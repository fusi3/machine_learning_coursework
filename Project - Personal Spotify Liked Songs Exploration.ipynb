# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
spotify = pd.read_csv('kaggle_personal_spotify_data.csv')

# %%
spotify.head(5)
# Out:
#    Unnamed: 0    artist_name        track_name                Track ID  \
# 0           0     Jason Mraz   I Won't Give Up  53QF56cjZA9RTuuMZDrSA6
# 1           1     Jason Mraz  93 Million Miles  1s8tP3jP4GZcyHDsjvw218
# 2           2  Joshua Hyslop  Do Not Let Me Go  7BRCa8MPiyuvr2VU3O9W0F
# 3           3   Boyce Avenue          Fast Car  63wsZUhUZLlh1OsyrZq7sz
# 4           4   Andrew Belle  Sky's Still Blue  6nXIYClvJAfi6ujLiKqEq8
#
#    popularity  year     genre  danceability  energy  key  ...  acousticness  \
# 0          68  2012  acoustic         0.483   0.303    4  ...        0.6940
# 1          50  2012  acoustic         0.572   0.454    3  ...        0.4770
# 2          57  2012  acoustic         0.409   0.234    3  ...        0.3380
# 3          58  2012  acoustic         0.392   0.251   10  ...        0.8070
# 4          54  2012  acoustic         0.430   0.791    6  ...        0.0726
#
#    instrumentalness  liveness  valence    tempo  duration_ms  time_signature  \
# ...

# %%
spotify.shape
# Out:
# (1159764, 23)

# %%
#filter_spotify = spotify[spotify['Source'] == ]
liked_spotify = spotify[pd.notnull(spotify['Source'])]
disliked_spotify = spotify[pd.isnull(spotify['Source'])]
disliked_spotify_sample = disliked_spotify.sample(n=8676) 

#liked_spotify.head(5)
#liked_spotify.shape
disliked_spotify_sample.tail(5)
# Out:
#         Unnamed: 0           artist_name  \
# 571455      571455     Vintage & Morelli
# 495472      495472           Killstation
# 251205      251205  Jean-Philippe Rameau
# 644248      648917         Kenny Burrell
# 87296        87296              Abhilash
#
#                                                track_name  \
# 571455                                         Crossroads
# 495472                                      WASTE MY TIME
# 251205  Suite in E Minor, RCT 2: No. 8, Tambourin - Ad...
# 644248  Out For Blood - 24-Bit Mastering; 2000 Digital...
# 87296                                    Hara Hara Shambo
#
#                       Track ID  popularity  year              genre  \
# 571455  4cYMKvTf9tf5VLOsISdXxF          34  2022  progressive-house
# 495472  4EleSuHrBKU8WNtrxIrlZR          37  2021                emo
# 251205  66SfJAISPtibHcxvT46JDN           7  2016              opera
# 644248  31i29xYKJsdEpKTZb2HSrq           3  2000             guitar
# ...

# %%
liked_genre = liked_spotify['genre'].value_counts()
liked_genre
# Out:
# hip-hop              176
# funk                 167
# jazz                  89
# soul                  89
# pop                   83
# dance                 79
# alt-rock              68
# blues                 65
# chill                 57
# disco                 56
# rock                  45
# indie-pop             42
# folk                  37
# electro               34
# hardcore              34
# french                18
# edm                   18
# acoustic              16
# singer-songwriter     15
# metal                 13
# deep-house            12
# garage                10
# house                 10
# groove                10
# ambient               10
# indian                 9
# afrobeat               9
# electronic             8
# guitar                 8
# hard-rock              6
# piano                  5
# emo                    4
# samba                  4
# country                3
# classical              3
# comedy                 3
# chicago-house          2
# ...

# %%
disliked_genre = disliked_spotify['genre'].value_counts()
disliked_genre
# Out:
# black-metal       21852
# gospel            21621
# ambient           21379
# acoustic          21081
# alt-rock          20850
#                   ...
# chicago-house      5168
# dubstep            4774
# detroit-techno     3920
# rock               3274
# songwriter          588
# Name: genre, Length: 82, dtype: int64

# %%
#the column genre will be removed from the machine learning model as including it will include an implicit bias
#i like both slow and fast songs but i know i do not like black metal songs and that would reflect in the data
#i should also check for corellation but checking correlation for a categorical is hard unless i turn it into binary
#it is also the case that the dimensionality would increase a lot with the genre column
#the other thing that i can do is that i can just use the numerical columns maybe but lets start doing it in matlab and see how
#far we get
